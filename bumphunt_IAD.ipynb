# %%
import bumphunt_plotting_utils as bp
import bumphunt_plotting_utils_no_labels as bpl
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as col

# %%
general_directory = "/hpcwork/zu992399/bumphunt_paper/"
general_directory_project = "/work/rwth0934/bumphunt_paper/"
general_directory_work = "/work/zu992399/bumphunt_paper/"
plotting_direc = "plots/sig_formula/"

min_error = -0.5
max_error = 2.2

min_sig = -1
max_sig = 14
max_sig_no = 5.5

# %% [markdown]
# # Baseline Dataset

# %%
folder = general_directory_project+"IAD_without_joep/"
results, rel_results, true_results, rel_error, exp = bp.bump_hunt(folder, err=[0,0,0])
IAD_error = np.mean(rel_error,axis=(1,2))

bp.plotting_error(rel_error, "IAD_without_joep", min=min_error, max=max_error)
print("alpha =", IAD_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))

IAD_stat = np.mean(exp,axis=(1,2))
IAD_sys = np.std(rel_error, axis=(1,2))
print("sys_err/stat_err =",IAD_stat)
bp.plotting(rel_results, true_results, "IAD_without_joep", min=min_sig, max = max_sig)
# Out:
# /work/rwth0934/bumphunt_paper/IAD_without_joep/
# alpha = [-0.007148    0.01222587  0.04611111]
# alpha_std = [0.04243086 0.10320454 0.35370779]
# sys_err/stat_err = [0.04021736 0.12516485 0.33966971]

# %%
folder = general_directory_project+"IAD_norm_joep/"
results, rel_results, true_results, rel_error, exp = bp.bump_hunt(folder, err=[0,0,0])
bp.plotting(rel_results, true_results, "IAD_norm_joep", min=min_sig, max = max_sig)
# Out:
# /work/rwth0934/bumphunt_paper/IAD_norm_joep/

# %%
folder = general_directory+"IAD_norm_joep_norand/"
results, rel_results, true_results, rel_error, exp, info = bp.bump_hunt(folder, err=[0,0,0], reuse=True)
bp.plotting(rel_results, true_results, "IAD_norm_joep", min=min_sig, max = max_sig)
print(rel_results.shape)
print(np.max(rel_results[:,4], axis=1))
print(np.mean(rel_results[:,4], axis=1))
print(np.mean(info["window5"][-1], axis=1))
# Out:
# /hpcwork/zu992399/bumphunt_paper/IAD_norm_joep_norand/
# (3, 9, 10)
# [7.10812345 9.45001912 8.02548614]
# [6.31183862 7.85928824 7.23115243]
# [0.01004955 0.00104361 0.00015461]

# %%
folder = general_directory+"IAD_norm_joep_rand_new/"
results, rel_results, true_results, rel_error, exp, info = bpl.bump_hunt(folder, err=[0,0,0], reuse=True)
bpl.plotting(rel_results, true_results, "IAD_norm_joep", min=min_sig, max = max_sig)

print(np.max(rel_results[:,4], axis=1))
print(np.mean(rel_results[:,4], axis=1))
print(np.mean(info["window5"][-1], axis=1))


colormap = col.get_cmap("RdBu")
sigs = [151,186,143,134,166,153,137,166,146,179]
colors = [colormap(1-(s-min(sigs))/(max(sigs)-min(sigs))) for s in sigs]
#bpl.plotting(rel_results, true_results, "cwola_norm_pythia_herwig", min=min_sig, max = max_sig)
bp.plotting_all(rel_results, true_results, "cwola_norm_pythia_herwig", min=min_sig, max = 12, colors_custom=colors, labels=sigs, BH_perc=0)
bp.plotting_all(rel_results, true_results, "cwola_norm_pythia_herwig", min=min_sig, max = 12, colors_custom=colors, labels=sigs, BH_perc=1)
bp.plotting_all(rel_results, true_results, "cwola_norm_pythia_herwig", min=min_sig, max = 12, colors_custom=colors, labels=sigs, BH_perc=2)
# Out:
# /hpcwork/zu992399/bumphunt_paper/IAD_norm_joep_rand_new/
# [ 7.99427581 12.12367336 10.33724525]
# [6.79733567 9.86076459 7.43461591]
# [0.0100459  0.00104323 0.00015455]
# yay
# [151, 186, 143, 134, 166, 153, 137, 166, 146, 179]
# /tmp/zu992399/login23-1_130840/ipykernel_49515/2300142786.py:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap = col.get_cmap("RdBu")
# yay
# [151, 186, 143, 134, 166, 153, 137, 166, 146, 179]
# yay
# [151, 186, 143, 134, 166, 153, 137, 166, 146, 179]

# %%
folder = general_directory+"IAD_reduced_stats_randsignal/"
results, rel_results, true_results, rel_error, exp, info = bpl.bump_hunt(folder, err=[0,0,0], reuse=True)
bpl.plotting(rel_results, true_results, "IAD_norm_joep", min=min_sig, max = 12)

print(np.max(rel_results[:,4], axis=1))
print(np.mean(rel_results[:,4], axis=1))
print(np.mean(info["window5"][-1], axis=1))

colormap = col.get_cmap("RdBu")
sigs = [151,186,143,134,166,153,137,166,146,179]
colors = [colormap(1-(s-min(sigs))/(max(sigs)-min(sigs))) for s in sigs]
bpl.plotting(rel_results, true_results, "cwola_norm_pythia_herwig", min=min_sig, max = max_sig)
bp.plotting_all(rel_results, true_results, "cwola_norm_pythia_herwig", min=min_sig, max = max_sig, colors_custom=colors, labels=sigs, BH_perc=0)
bp.plotting_all(rel_results, true_results, "cwola_norm_pythia_herwig", min=min_sig, max = max_sig, colors_custom=colors, labels=sigs, BH_perc=1)
bp.plotting_all(rel_results, true_results, "cwola_norm_pythia_herwig", min=min_sig, max = max_sig, colors_custom=colors, labels=sigs, BH_perc=2)
# Out:
# /hpcwork/zu992399/bumphunt_paper/IAD_reduced_stats_randsignal/
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 folder = general_directory+"IAD_reduced_stats_randsignal/"
# ----> 2 results, rel_results, true_results, rel_error, exp, info = bpl.bump_hunt(folder, err=[0,0,0], reuse=True)
#       3 bpl.plotting(rel_results, true_results, "IAD_norm_joep", min=min_sig, max = 12)
#       5 print(np.max(rel_results[:,4], axis=1))
#
# File /rwthfs/rz/cluster/home/zu992399/PhD/bumphunt_paper/bumphunt_plotting_utils_no_labels.py:126, in bump_hunt(folder, err, err_err, runs, turn_around, reuse)
#     123     err_err = err
#     125 for window in range(9):
# ...

# %%
folder = general_directory+"IAD_norm_joep_extra_test/window5_"
results, rel_results, true_results, rel_error, exp, info = bpl.bump_hunt_single_window(folder, 5, err=[0,0,0], err_err =[0,0,0])
#bpl.plotting(rel_results, true_results, "IAD_norm_joep", min=min_sig, max = 12)

print(np.max(rel_results, axis=1))
print(np.mean(rel_results, axis=1))
print(np.mean(info[-1], axis=1))
# Out:
# [ 7.77403365 12.75787897  9.89399295]
# [6.84248211 9.89974186 7.23334613]
# [0.0100459  0.00104323 0.00015455]

# %% [markdown]
# ## Baseline + $\Delta R$ Dataset

# %%
folder = general_directory_project+"IAD_without_DR_joep/"
results, rel_results, true_results, rel_error, exp = bp.bump_hunt(folder, err=[0,0,0])
IAD_DR_error = np.mean(rel_error,axis=(1,2))

bp.plotting_error(rel_error, "IAD_without_DR_joep", min=min_error, max=max_error)
print("alpha =", IAD_DR_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))

IAD_DR_stat = np.mean(exp,axis=(1,2))
IAD_DR_sys = np.std(rel_error, axis=(1,2))
print("sys_err/stat_err =",IAD_DR_stat)
bp.plotting(rel_results, true_results, "IAD_without_DR_joep", min=min_sig, max = max_sig)
# Out:
# /work/rwth0934/bumphunt_paper/IAD_without_DR_joep/
# alpha = [0.01050541 0.06450637 0.20133333]
# alpha_std = [0.03542393 0.1121342  0.39494203]
# sys_err/stat_err = [0.04021745 0.12516485 0.33966971]

# %%
folder = general_directory_project+"IAD_norm_DR_joep/"
results, rel_results, true_results, rel_error, exp = bp.bump_hunt(folder, err=[0,0,0])
bp.plotting(rel_results, true_results, "IAD_norm_DR_joep", min=min_sig, max = max_sig)
# Out:
# /work/rwth0934/bumphunt_paper/IAD_norm_DR_joep/
