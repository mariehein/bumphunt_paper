# %% [markdown]
# # Bump Hunt Plotting for CWoLa

# %%
import bumphunt_plotting_utils as bp
import numpy as np
import matplotlib.pyplot as plt
import bumphunt_plotting_utils_no_labels as bpl
import matplotlib.cm as col

# %%
general_directory = "/hpcwork/zu992399/bumphunt_paper/"
general_directory_project = "/work/rwth0934/bumphunt_paper/"
general_directory_work = "/work/zu992399/bumphunt_paper/"
plotting_direc = "plots/sig_formula/"

min_error = -0.5
max_error = 2.2

min_sig = -1
max_sig = 14
max_sig_no = 5.5

# %% [markdown]
# ## Baseline Dataset

# %%
folder = general_directory+"cwola_herwig_without_2/"
results, rel_results, true_results, rel_error, exp = bp.bump_hunt(folder)
cwola_herwig_error = np.mean(rel_error,axis=(1,2))

bp.plotting_error(rel_error, "cwola_without_herwig", min=min_error, max=max_error)
cwola_herwig_stat = np.mean(exp,axis=(1,2))
cwola_herwig_sys = np.std(rel_error, axis=(1,2))
print("alpha =",cwola_herwig_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))
print("sys_err/stat_err =",cwola_herwig_stat)
# Out:
# /hpcwork/zu992399/bumphunt_paper/cwola_herwig_without_2/
# alpha = [0.13954379 0.11473376 0.04827641]
# alpha_std = [0.04539765 0.18010538 0.31591527]
# sys_err/stat_err = [0.0405328  0.12560472 0.34561306]

# %%
folder = general_directory+"cwola_without/"
results, rel_results, true_results, rel_error, exp, info = bp.bump_hunt(folder, reuse=True)
cwola_error = np.mean(rel_error,axis=(1,2))

bp.plotting_error(rel_error, "cwola_without", min=min_error, max=max_error)
cwola_stat = np.mean(exp,axis=(1,2))
cwola_sys = np.std(rel_error, axis=(1,2))
print("alpha =", cwola_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))
print("stat =", cwola_stat)

results, rel_results, true_results, rel_error, exp = bp.bump_hunt_reuse(info, err=cwola_herwig_error)
bp.plotting(rel_results, true_results, "cwola_without_pythia_herwig", min=min_sig, max = max_sig_no)

err = np.array([max([cwola_herwig_sys[i],cwola_herwig_error[i]]) for i in range(3)])
results, rel_results, true_results, rel_error, exp = bp.bump_hunt_reuse(info, err=cwola_herwig_error, err_err=err)
bp.plotting(rel_results, true_results, "cwola_without_pythia_herwig", min=min_sig, max = max_sig_no)
# Out:
# /hpcwork/zu992399/bumphunt_paper/cwola_without/
# alpha = [0.13747762 0.16111538 0.19623152]
# alpha_std = [0.07155704 0.16644098 0.37281859]
# stat = [0.04069738 0.12570735 0.34592745]

# %%
folder = general_directory+"cwola_norm/"
results, rel_results, true_results, rel_error, exp, info = bp.bump_hunt(folder, err=cwola_herwig_error, reuse=True)
bp.plotting(rel_results, true_results, "cwola_norm_pythia_herwig", min=min_sig, max = max_sig)
# Out:
# /hpcwork/zu992399/bumphunt_paper/cwola_norm/

# %%
folder = general_directory+"cwola_baseline_norm/"
results, rel_results, true_results, rel_error, exp, info = bp.bump_hunt(folder, err=cwola_herwig_error, reuse=True)
bp.plotting(rel_results, true_results, "cwola_norm_pythia_herwig", min=min_sig, max = max_sig)
# Out:
# /hpcwork/zu992399/bumphunt_paper/cwola_baseline_norm/

# %%
folder = general_directory+"cwola_baseline_norm_randsignal/"
results, rel_results, true_results, rel_error, exp, info = bpl.bump_hunt(folder, err=cwola_herwig_error, reuse=True)
bpl.plotting(rel_results, true_results, "cwola_norm_pythia_herwig_rand", min=min_sig, max = max_sig)
# Out:
# /hpcwork/zu992399/bumphunt_paper/cwola_baseline_norm_randsignal/

# %%
colormap = col.get_cmap("RdBu")
sigs = [151,186,143,134,166,153,137,166,146,179]
colors = [colormap(1-(s-min(sigs))/(max(sigs)-min(sigs))) for s in sigs]
#[colormap([[s/max(sigs)] for s in sigs])]
folder = general_directory+"cwola_baseline_norm_randsignal2/"
results, rel_results, true_results, rel_error, exp, info = bpl.bump_hunt(folder, err=cwola_herwig_error, reuse=True)
bpl.plotting(rel_results, true_results, "cwola_norm_pythia_herwig_rand", min=min_sig, max = max_sig)
bp.plotting_all(rel_results, true_results, "cwola_norm_pythia_herwig", min=min_sig, max = 12, colors_custom=colors, labels=sigs, BH_perc=0)
bp.plotting_all(rel_results, true_results, "cwola_norm_pythia_herwig", min=min_sig, max = 12, colors_custom=colors, labels=sigs, BH_perc=1)
bp.plotting_all(rel_results, true_results, "cwola_norm_pythia_herwig", min=min_sig, max = 12, colors_custom=colors, labels=sigs, BH_perc=2)
# Out:
# /tmp/zu992399/login23-1_130840/ipykernel_162571/3522080673.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap = col.get_cmap("RdBu")
# /hpcwork/zu992399/bumphunt_paper/cwola_baseline_norm_randsignal2/
# yay
# [151, 186, 143, 134, 166, 153, 137, 166, 146, 179]
# yay
# [151, 186, 143, 134, 166, 153, 137, 166, 146, 179]
# yay
# [151, 186, 143, 134, 166, 153, 137, 166, 146, 179]

# %% [markdown]
# ## Baseline + $\Delta R$ Dataset

# %%
folder = general_directory+"cwola_herwig_DR_without_new/"
results, rel_results, true_results, rel_error, exp = bp.bump_hunt(folder)
cwola_herwig_DR_error = np.mean(rel_error,axis=(1,2))

bp.plotting_error(rel_error, "cwola_DR_without_herwig", min=min_error, max=max_error)
cwola_herwig_DR_stat = np.mean(exp,axis=(1,2))
cwola_herwig_DR_sys = np.std(rel_error, axis=(1,2))
print("alpha =",cwola_herwig_DR_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))
print("sys_err/stat_err =",cwola_herwig_DR_stat)
# Out:
# /hpcwork/zu992399/bumphunt_paper/cwola_herwig_DR_without_new/
# alpha = [0.98419592 1.04681583 0.93846999]
# alpha_std = [0.12635498 0.21511048 0.49278164]
# sys_err/stat_err = [0.0405332  0.12560472 0.34561306]

# %%
folder = general_directory+"cwola_baseline_DR_without_new/"
results, rel_results, true_results, rel_error, exp, info = bp.bump_hunt(folder, reuse=True)
cwola_DR_error = np.mean(rel_error,axis=(1,2))

bp.plotting_error(rel_error, "cwola_DR_without", min=min_error, max=max_error)
cwola_DR_stat = np.mean(exp,axis=(1,2))
cwola_DR_sys = np.std(rel_error, axis=(1,2))
print("alpha =",cwola_DR_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))
print("sys_err/stat_err =",cwola_DR_stat)

results, rel_results, true_results, rel_error, exp = bp.bump_hunt_reuse(info, err=cwola_herwig_DR_error)
bp.plotting(rel_results, true_results, "cwola_without_DR_pythia_herwig", min=min_sig, max = max_sig_no)
# Out:
# /hpcwork/zu992399/bumphunt_paper/cwola_baseline_DR_without_new/
# alpha = [1.01035764 1.01588029 1.01745145]
# alpha_std = [0.13759351 0.22796632 0.63747237]
# sys_err/stat_err = [0.04069738 0.12570735 0.34592745]

# %%
folder = general_directory+"cwola_baseline_DR_norm_new/"
results, rel_results, true_results, rel_error, exp = bp.bump_hunt(folder, err=cwola_herwig_DR_error)
bp.plotting(rel_results, true_results, "cwola_norm_DR_pythia_herwig", min=min_sig, max = max_sig)
# Out:
# /hpcwork/zu992399/bumphunt_paper/cwola_baseline_DR_norm_new/

# %%
folder = general_directory+"cwola_baseline_DR_norm_randsignal/"
results, rel_results, true_results, rel_error, exp = bpl.bump_hunt(folder, err=cwola_herwig_DR_error)
bpl.plotting(rel_results, true_results, "cwola_norm_DR_pythia_herwig", min=min_sig, max = max_sig)
# Out:
# /hpcwork/zu992399/bumphunt_paper/cwola_baseline_DR_norm_randsignal/
