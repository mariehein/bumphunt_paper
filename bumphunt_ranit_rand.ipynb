# %%
import bumphunt_plotting_utils as bp
import numpy as np
import matplotlib.pyplot as plt

# %%
general_directory = "/hpcwork/zu992399/bumphunt_paper/"
general_directory_project = "/work/rwth0934/bumphunt_paper/"
general_directory_work = "/work/zu992399/bumphunt_paper/"
plotting = "plots/testing/"

min_error = -0.5
max_error = 2.2

min_sig = -1
max_sig = 10
max_sig_no = 5.5

# %% [markdown]
# ## Baseline without Signal

# %%
folder = general_directory_project+"cathode_without_SB_stats_ranit_rand/"
results, rel_results, true_results, rel_error, exp = bp.bump_hunt(folder)
ranit_SB_error = np.mean(rel_error,axis=(1,2))
cathode_stat = np.mean(exp,axis=(1,2))
cathode_sys_SB = np.std(rel_error, axis=(1,2))
print("alpha =",ranit_SB_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))
print("stat_error =",cathode_stat)
bp.plotting_error(rel_error, "cathode_without", min=min_error, max=max_error, plotting_directory=plotting)
# Out:
# /work/rwth0934/bumphunt_paper/cathode_without_SB_stats_ranit_rand/
# alpha = [0.01118832 0.08437766 0.76753631]
# alpha_std = [0.03678172 0.10366477 0.38959507]
# stat_error = [0.02958956 0.09353835 0.29504698]

# %%
folder = general_directory_project+"cathode_without_ranit_rand/"
results, rel_results, true_results, rel_error, exp, info = bp.bump_hunt(folder, reuse=True)
cathode_error = np.mean(rel_error,axis=(1,2))
cathode_stat = np.mean(exp,axis=(1,2))
cathode_sys = np.std(rel_error, axis=(1,2))
print("alpha =",cathode_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))
print("stat_error =",cathode_stat)
bp.plotting_error(rel_error, "cathode_without_ranit", min=min_error, max=max_error, plotting_directory =plotting)

results, rel_results, true_results, rel_error, exp = bp.bump_hunt_reuse(info, err=ranit_SB_error, err_err=ranit_SB_error)
bp.plotting(rel_results, true_results, "ranit_without_SB", min=min_sig, max = max_sig_no, plotting_directory=plotting)

results, rel_results, true_results, rel_error, exp = bp.bump_hunt_reuse(info, err=ranit_SB_error, err_err=cathode_sys_SB)
bp.plotting(rel_results, true_results, "ranit_without_SB", min=min_sig, max = max_sig_no, plotting_directory=plotting)

err = np.array([max([cathode_sys_SB[i],ranit_SB_error[i]]) for i in range(3)])
results, rel_results, true_results, rel_error, exp = bp.bump_hunt_reuse(info, err=ranit_SB_error, err_err=err)
bp.plotting(rel_results, true_results, "ranit_without_SB", min=min_sig, max = max_sig_no, plotting_directory=plotting)
# Out:
# /work/rwth0934/bumphunt_paper/cathode_without_ranit_rand/
# alpha = [0.06410406 0.15612084 0.70802941]
# alpha_std = [0.03740538 0.10173067 0.46479145]
# stat_error = [0.02958955 0.09353842 0.2950474 ]

# %% [markdown]
# ## Baseline with Signal

# %%
folder = general_directory_project+"cathode_norm_SB_stats_ranit_rand/"
results, rel_results, true_results, rel_error, exp = bp.bump_hunt(folder)
ranit_SB_error = np.mean(rel_error,axis=(1,2))
cathode_stat = np.mean(exp,axis=(1,2))
cathode_sys_SB = np.std(rel_error, axis=(1,2))
print("alpha =",ranit_SB_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))
print("stat_error =",cathode_stat)
bp.plotting_error(rel_error, "cathode_norm", min=min_error, max=max_error, plotting_directory=plotting)
# Out:
# /work/rwth0934/bumphunt_paper/cathode_norm_SB_stats_ranit_rand/
# alpha = [0.01527137 0.12578739 0.90457639]
# alpha_std = [0.02915701 0.10608546 0.63233261]
# stat_error = [0.0295374  0.09337403 0.294368  ]

# %%
folder = general_directory_project+"cathode_norm_ranit_rand/"
results, rel_results, true_results, rel_error, exp, info = bp.bump_hunt(folder, err=ranit_SB_error, reuse=True)
bp.plotting(rel_results, true_results, "ranit_norm_SB", min=min_sig, max = 15, plotting_directory=plotting)

results, rel_results, true_results, rel_error, exp = bp.bump_hunt_reuse(info, err=ranit_SB_error, err_err=cathode_sys_SB)
bp.plotting(rel_results, true_results, "ranit_norm_SB", min=min_sig, max = 15, plotting_directory=plotting)

err = np.array([max([cathode_sys_SB[i],ranit_SB_error[i]]) for i in range(3)])
results, rel_results, true_results, rel_error, exp = bp.bump_hunt_reuse(info, err=ranit_SB_error, err_err=err)
bp.plotting(rel_results, true_results, "ranit_norm_SB", min=min_sig, max = 15, plotting_directory=plotting)
# Out:
# /work/rwth0934/bumphunt_paper/cathode_norm_ranit_rand/

# %% [markdown]
# ## Baseline + $\Delta R$ without Signal

# %%
folder = general_directory_project+"cathode_without_DR_SB_stats_ranit_rand/"
results, rel_results, true_results, rel_error, exp = bp.bump_hunt(folder)
ranit_SB_error = np.mean(rel_error,axis=(1,2))
cathode_stat = np.mean(exp,axis=(1,2))
cathode_sys_SB = np.std(rel_error, axis=(1,2))
print("alpha =",ranit_SB_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))
print("stat_error =",cathode_stat)
bp.plotting_error(rel_error, "cathode_DR_without_SB", min=min_error, max=max_error, plotting_directory=plotting)
# Out:
# /work/rwth0934/bumphunt_paper/cathode_without_DR_SB_stats_ranit_rand/
# alpha = [0.06238918 0.09720482 0.65732502]
# alpha_std = [0.05063405 0.12783587 0.55457503]
# stat_error = [0.02958956 0.09353849 0.29504946]

# %%
folder = general_directory_project+"cathode_without_DR_ranit_rand/"
results, rel_results, true_results, rel_error, exp, info = bp.bump_hunt(folder, reuse=True)
cathode_error = np.mean(rel_error,axis=(1,2))
cathode_stat = np.mean(exp,axis=(1,2))
cathode_sys = np.std(rel_error, axis=(1,2))
print("alpha =",cathode_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))
print("stat_error =",cathode_stat)
bp.plotting_error(rel_error, "cathode_without_ranit", min=min_error, max=max_error, plotting_directory =plotting)

results, rel_results, true_results, rel_error, exp = bp.bump_hunt_reuse(info, err=ranit_SB_error, err_err=ranit_SB_error)
bp.plotting(rel_results, true_results, "ranit_without_SB", min=min_sig, max = max_sig_no, plotting_directory=plotting)

results, rel_results, true_results, rel_error, exp = bp.bump_hunt_reuse(info, err=ranit_SB_error, err_err=cathode_sys_SB)
bp.plotting(rel_results, true_results, "ranit_without_SB", min=min_sig, max = max_sig_no, plotting_directory=plotting)

err = np.array([max([cathode_sys_SB[i],ranit_SB_error[i]]) for i in range(3)])
results, rel_results, true_results, rel_error, exp = bp.bump_hunt_reuse(info, err=ranit_SB_error, err_err=err)
bp.plotting(rel_results, true_results, "ranit_without_SB", min=min_sig, max = max_sig_no, plotting_directory=plotting)
# Out:
# /work/rwth0934/bumphunt_paper/cathode_without_DR_ranit_rand/
# /rwthfs/rz/cluster/home/zu992399/PhD/bumphunt_paper/bumphunt_plotting_utils.py:106: RuntimeWarning: invalid value encountered in true_divide
#   eff_eff = N_samples_after/N_samples
# /rwthfs/rz/cluster/home/zu992399/PhD/bumphunt_paper/bumphunt_plotting_utils.py:55: RuntimeWarning: divide by zero encountered in true_divide
#   stat_err = np.sqrt(1/N_b_exp+1/N_samples_after)
# /rwthfs/rz/cluster/home/zu992399/PhD/bumphunt_paper/bumphunt_plotting_utils.py:56: RuntimeWarning: divide by zero encountered in true_divide
#   samples_err = np.sqrt(1/N_samples_after)
# /rwthfs/rz/cluster/home/zu992399/PhD/bumphunt_paper/bumphunt_plotting_utils.py:61: RuntimeWarning: invalid value encountered in true_divide
#   true_results = N_sig/np.sqrt(N_bkg)
# alpha = [nan nan nan]
# alpha_std = [nan nan nan]
# stat_error = [nan nan nan]
# ...

# %% [markdown]
# ## Baseline + $\Delta R$ with signal

# %%
folder = general_directory_work+"cathode_norm_DR_SB_stats_ranit_rand/"
results, rel_results, true_results, rel_error, exp = bp.bump_hunt(folder)
ranit_SB_error = np.mean(rel_error,axis=(1,2))
cathode_stat = np.mean(exp,axis=(1,2))
cathode_sys_SB = np.std(rel_error, axis=(1,2))
print("alpha =",ranit_SB_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))
print("stat_error =",cathode_stat)
bp.plotting_error(rel_error, "cathode_DR_norm_SB", min=min_error, max=max_error, plotting_directory=plotting)
# Out:
# /work/zu992399/bumphunt_paper/cathode_norm_DR_SB_stats_ranit_rand/
# alpha = [0.07237724 0.15607246 0.78885383]
# alpha_std = [0.06238144 0.15032744 0.6607656 ]
# stat_error = [0.02953741 0.0933741  0.29437024]

# %%
folder = general_directory_work+"cathode_norm_DR_ranit_rand/"
results, rel_results, true_results, rel_error, exp, info = bp.bump_hunt(folder, err=ranit_SB_error, reuse=True)
bp.plotting(rel_results, true_results, "ranit_norm_SB", min=min_sig, max = 15, plotting_directory=plotting)

results, rel_results, true_results, rel_error, exp = bp.bump_hunt_reuse(info, err=ranit_SB_error, err_err=cathode_sys_SB)
bp.plotting(rel_results, true_results, "ranit_norm_SB", min=min_sig, max = 15, plotting_directory=plotting)

err = np.array([max([cathode_sys_SB[i],ranit_SB_error[i]]) for i in range(3)])
results, rel_results, true_results, rel_error, exp = bp.bump_hunt_reuse(info, err=ranit_SB_error, err_err=err)
bp.plotting(rel_results, true_results, "ranit_norm_SB", min=min_sig, max = 15, plotting_directory=plotting)
# Out:
# /work/zu992399/bumphunt_paper/cathode_norm_DR_ranit_rand/
