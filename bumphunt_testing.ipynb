# %%
import bumphunt_plotting_utils as bp
import numpy as np
import matplotlib.pyplot as plt

# %%
general_directory = "/hpcwork/zu992399/bumphunt_paper/"
general_directory_project = "/work/rwth0934/bumphunt_paper/"
general_directory_work = "/work/zu992399/bumphunt_paper/"
plotting = "plots/testing/"

min_error = -0.5
max_error = 2.2

min_sig = -1
max_sig = 10
max_sig_no = 5.5

# %% [markdown]
# ## Baseline without Signal

# %%
folder = general_directory_project+"cathode_without_ranit_SB_stats/"
results, rel_results, true_results, rel_error, exp = bp.bump_hunt(folder)
ranit_SB_error = np.mean(rel_error,axis=(1,2))
cathode_stat = np.mean(exp,axis=(1,2))
cathode_sys = np.std(rel_error, axis=(1,2))
print("alpha =",ranit_SB_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))
print("stat_error =",cathode_stat)
bp.plotting_error(rel_error, "cathode_without", min=min_error, max=max_error, plotting_directory=plotting)
# Out:
# /work/rwth0934/bumphunt_paper/cathode_without_ranit_SB_stats/
# alpha = [-0.0009759   0.07546186  0.76765215]
# alpha_std = [0.03259823 0.07911763 0.26141846]
# stat_error = [0.02958955 0.09353842 0.29504946]

# %%
folder = general_directory_project+"cathode_without_ranit_rand/"
results, rel_results, true_results, rel_error, exp = bp.bump_hunt(folder)
ranit_SB_error = np.mean(rel_error,axis=(1,2))
cathode_stat = np.mean(exp,axis=(1,2))
cathode_sys = np.std(rel_error, axis=(1,2))
print("alpha =",ranit_SB_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))
print("stat_error =",cathode_stat)
bp.plotting_error(rel_error, "cathode_without", min=min_error, max=max_error, plotting_directory=plotting)
# Out:
# /work/rwth0934/bumphunt_paper/cathode_without_ranit_rand/
# alpha = [0.06410406 0.15612084 0.70802941]
# alpha_std = [0.03740538 0.10173067 0.46479145]
# stat_error = [0.02958955 0.09353842 0.2950474 ]

# %%
bp.plotting_error(rel_error, "cathode_without", min=min_error, max=0.5, plotting_directory=plotting)

# %%
cathode_sys = [-0.0009759,   0.07546186,  0.76765215]
cathode_sys_err = [0.03259823, 0.07911763, 0.26141846]
cathode_sys_err = np.array([max([cathode_sys[i],cathode_sys_err[i]]) for i in range(3)])
print(cathode_sys_err)
# Out:
# [0.03259823 0.07911763 0.76765215]

# %%
folder = general_directory_project+"cathode_without_ranit/"
results, rel_results, true_results, rel_error, exp, info = bp.bump_hunt(folder, reuse=True)
cathode_error = np.mean(rel_error,axis=(1,2))
cathode_stat = np.mean(exp,axis=(1,2))
cathode_sys = np.std(rel_error, axis=(1,2))
print("alpha =",cathode_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))
print("stat_error =",cathode_stat)
bp.plotting_error(rel_error, "cathode_without_ranit", min=min_error, max=max_error, plotting_directory =plotting)

results, rel_results, true_results, rel_error, exp = bp.bump_hunt_reuse(info, err=cathode_sys, err_err=cathode_sys_err)
bp.plotting(rel_results, true_results, "ranit_without_SB", min=min_sig, max = max_sig_no, plotting_directory=plotting)
# Out:
# /work/rwth0934/bumphunt_paper/cathode_without_ranit/
# alpha = [0.06049236 0.16561704 0.77610603]
# alpha_std = [0.02890232 0.10586526 0.45917812]
# stat_error = [0.02958955 0.09353849 0.29504946]

# %%
folder = general_directory_project+"cathode_without_ranit/"
results, rel_results, true_results, rel_error, exp, info = bp.bump_hunt(folder, reuse=True)
cathode_error = np.mean(rel_error,axis=(1,2))
cathode_stat = np.mean(exp,axis=(1,2))
cathode_sys = np.std(rel_error, axis=(1,2))
print("alpha =",cathode_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))
print("stat_error =",cathode_stat)
bp.plotting_error(rel_error, "cathode_without_ranit", min=min_error, max=max_error, plotting_directory =plotting)

results, rel_results, true_results, rel_error, exp = bp.bump_hunt_reuse(info, err=np.where(ranit_SB_error<0, 0,ranit_SB_error))
bp.plotting(rel_results, true_results, "ranit_without_SB", min=min_sig, max = max_sig_no, plotting_directory=plotting)
# Out:
# /work/rwth0934/bumphunt_paper/cathode_without_ranit/
# alpha = [0.06049236 0.16561704 0.77610603]
# alpha_std = [0.02890232 0.10586526 0.45917812]
# stat_error = [0.02958955 0.09353849 0.29504946]

# %% [markdown]
# ## Baseline with Signal

# %%
folder = general_directory_project+"cathode_norm_ranit_SB_stats/"
results, rel_results, true_results, rel_error, exp = bp.bump_hunt(folder)
ranit_SB_error = np.mean(rel_error,axis=(1,2))
cathode_stat = np.mean(exp,axis=(1,2))
cathode_sys = np.std(rel_error, axis=(1,2))
print("alpha =",ranit_SB_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))
print("stat_error =",cathode_stat)
bp.plotting_error(rel_error, "cathode_norm", min=min_error, max=max_error, plotting_directory=plotting)
# Out:
# /work/rwth0934/bumphunt_paper/cathode_norm_ranit_SB_stats/
# alpha = [0.01400556 0.10411183 0.98749032]
# alpha_std = [0.02967933 0.12278034 0.70729221]
# stat_error = [0.0295374  0.09337404 0.29437024]

# %%
folder = general_directory_project+"cathode_norm_ranit/"
results, rel_results, true_results, rel_error, exp = bp.bump_hunt(folder, err=np.where(ranit_SB_error<0, 0,ranit_SB_error))
bp.plotting(rel_results, true_results, "ranit_norm_SB", min=min_sig, max = 15, plotting_directory=plotting)
# Out:
# /work/rwth0934/bumphunt_paper/cathode_norm_ranit/

# %% [markdown]
# ## Baseline + $\Delta R$ without Signal

# %%
folder = general_directory_project+"cathode_without_DR_ranit_SB_stats/"
results, rel_results, true_results, rel_error, exp = bp.bump_hunt(folder)
ranit_SB_error = np.mean(rel_error,axis=(1,2))
cathode_stat = np.mean(exp,axis=(1,2))
cathode_sys = np.std(rel_error, axis=(1,2))
print("alpha =",ranit_SB_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))
print("stat_error =",cathode_stat)
bp.plotting_error(rel_error, "cathode_DR_without_SB", min=min_error, max=max_error, plotting_directory=plotting)
# Out:
# /work/rwth0934/bumphunt_paper/cathode_without_DR_ranit_SB_stats/
# alpha = [0.0654921  0.08354724 0.55935517]
# alpha_std = [0.05660465 0.1688992  0.49213662]
# stat_error = [0.02958956 0.09353849 0.29504946]

# %%
folder = general_directory_project+"cathode_without_DR_ranit/"
results, rel_results, true_results, rel_error, exp, info = bp.bump_hunt(folder, reuse=True)
cathode_error = np.mean(rel_error,axis=(1,2))
cathode_stat = np.mean(exp,axis=(1,2))
cathode_sys = np.std(rel_error, axis=(1,2))
print("alpha =",cathode_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))
print("stat_error =",cathode_stat)
bp.plotting_error(rel_error, "cathode_without_ranit", min=min_error, max=max_error, plotting_directory =plotting)

results, rel_results, true_results, rel_error, exp = bp.bump_hunt_reuse(info, err=np.where(ranit_SB_error<0, 0,ranit_SB_error))
bp.plotting(rel_results, true_results, "ranit_without_SB", min=min_sig, max = max_sig_no, plotting_directory=plotting)
# Out:
# /work/rwth0934/bumphunt_paper/cathode_without_DR_ranit/
# alpha = [0.14435584 0.27207475 0.60550236]
# alpha_std = [0.04098843 0.1107441  0.64829175]
# stat_error = [0.02958956 0.09353849 0.29504946]

# %% [markdown]
# ## Baseline + $\Delta R$ with signal

# %%
folder = general_directory_project+"cathode_norm_DR_ranit_SB_stats/"
results, rel_results, true_results, rel_error, exp = bp.bump_hunt(folder)
ranit_SB_error = np.mean(rel_error,axis=(1,2))
cathode_stat = np.mean(exp,axis=(1,2))
cathode_sys = np.std(rel_error, axis=(1,2))
print("alpha =",ranit_SB_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))
print("stat_error =",cathode_stat)
bp.plotting_error(rel_error, "cathode_DR_norm_SB", min=min_error, max=max_error, plotting_directory=plotting)
# Out:
# /work/rwth0934/bumphunt_paper/cathode_norm_DR_ranit_SB_stats/
# alpha = [0.05837593 0.13718641 0.72352821]
# alpha_std = [0.04733964 0.17089324 0.53662748]
# stat_error = [0.02953741 0.0933741  0.29437024]

# %%
folder = general_directory_project+"cathode_norm_DR_ranit/"
results, rel_results, true_results, rel_error, exp = bp.bump_hunt(folder, err=np.where(ranit_SB_error<0, 0,ranit_SB_error))
bp.plotting(rel_results, true_results, "ranit_norm_SB", min=min_sig, max = 15, plotting_directory=plotting)
# Out:
# /work/rwth0934/bumphunt_paper/cathode_norm_DR_ranit/
