# %% [markdown]
# # Significance plotting for CATHODE

# %%
import bumphunt_plotting_utils as bp
import numpy as np

# %%
general_directory = "/hpcwork/zu992399/bumphunt_paper/"
general_directory_project = "/work/rwth0934/bumphunt_paper/"
general_directory_work = "/work/zu992399/bumphunt_paper/"

min_error = -0.5
max_error = 2.2

min_sig = -1
max_sig = 10
max_sig_Herwig = 14
max_sig_no = 5.5

save=True

# %% [markdown]
# ## Baseline dataset without signal

# %%
folder = general_directory+"cathode_without_Herwig_ranit_rand/"
rel_results, rel_error, exp = bp.bump_hunt(folder)
ranit_Herwig_error = np.mean(rel_error,axis=(1,2))
cathode_stat = np.mean(exp,axis=(1,2))
cathode_sys_Herwig = np.std(rel_error, axis=(1,2))
print("alpha =",ranit_Herwig_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))
print("stat_error =",cathode_stat)
bp.plotting_error(rel_error, "cathode_Herwig", min=min_error, max=max_error, save=save)
# Out:
# alpha = [0.06888982 0.13948342 0.25105146]
# alpha_std = [0.03566025 0.11513795 0.32127425]
# stat_error = [0.02945285 0.09310623 0.29358095]

# %%
folder = general_directory_project+"cathode_without_SB_stats_ranit_rand/"
rel_results, rel_error, exp = bp.bump_hunt(folder)
ranit_SB_error = np.mean(rel_error,axis=(1,2))
cathode_stat = np.mean(exp,axis=(1,2))
cathode_sys_SB = np.std(rel_error, axis=(1,2))
print("alpha =",ranit_SB_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))
print("stat_error =",cathode_stat)
bp.plotting_error(rel_error, "cathode_SB_without", min=min_error, max=max_error, save=save)
# Out:
# alpha = [0.01118832 0.08437766 0.76753631]
# alpha_std = [0.03678172 0.10366477 0.38959507]
# stat_error = [0.02958956 0.09353835 0.29504698]

# %%
folder = general_directory_project+"cathode_without_ranit_rand/"
rel_results, rel_error, exp = bp.bump_hunt(folder)
cathode_error = np.mean(rel_error,axis=(1,2))
cathode_stat = np.mean(exp,axis=(1,2))
cathode_sys = np.std(rel_error, axis=(1,2))
print("alpha =",cathode_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))
print("stat_error =",cathode_stat)
bp.plotting_error(rel_error, "cathode_without", min=min_error, max=max_error, save=save)

rel_results, rel_error, exp = bp.bump_hunt(folder, err=ranit_SB_error)
bp.plotting(rel_results, "cathode_without_SB", min=min_sig, max = max_sig_no, save=save)

rel_results, rel_error, exp = bp.bump_hunt(folder, err=ranit_Herwig_error)
bp.plotting(rel_results, "cathode_without_Herwig", min=min_sig, max = max_sig_no, save=save)

err = np.array([max([ranit_SB_error[i],ranit_Herwig_error[i]]) for i in range(3)])
rel_results, rel_error, exp = bp.bump_hunt(folder, err=err)
bp.plotting(rel_results, "cathode_without_Herwig_SB", min=min_sig, max = max_sig_no, save=save)

err = np.array([np.sqrt(ranit_SB_error[i]**2+ranit_Herwig_error[i]**2) for i in range(3)])
print("alpha quad combine = ", err)
rel_results, rel_error, exp = bp.bump_hunt(folder, err=err)
bp.plotting(rel_results, "cathode_without_Herwig_SB_quad", min=min_sig, max = max_sig_no, save=save)


err = np.array([np.sqrt(ranit_SB_error[i]**2+ranit_Herwig_error[i]**2) for i in range(3)])
print("alpha quad combine = ", err)
rel_results, rel_error, exp = bp.bump_hunt(folder, err=err, err_err=np.array([0,0,0]))
bp.plotting(rel_results, "cathode_without_Herwig_SB_quad", min=min_sig, max = max_sig_no, save=False)
# Out:
# alpha = [0.06410406 0.15612084 0.70802941]
# alpha_std = [0.03740538 0.10173067 0.46479145]
# stat_error = [0.02958955 0.09353842 0.2950474 ]
# alpha quad combine =  [0.06979245 0.16301907 0.80755112]
# alpha quad combine =  [0.06979245 0.16301907 0.80755112]

# %% [markdown]
# ## Baseline dataset with signal

# %%
folder = general_directory_project+"cathode_norm_SB_stats_ranit_rand/"
rel_results, rel_error, exp = bp.bump_hunt(folder)
ranit_SB_error = np.mean(rel_error,axis=(1,2))
cathode_stat = np.mean(exp,axis=(1,2))
cathode_sys_SB = np.std(rel_error, axis=(1,2))
print("alpha =",ranit_SB_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))
print("stat_error =",cathode_stat)
bp.plotting_error(rel_error, "cathode_norm_SB", min=min_error, max=max_error, save=save)
# Out:
# alpha = [0.01527137 0.12578739 0.90457639]
# alpha_std = [0.02915701 0.10608546 0.63233261]
# stat_error = [0.0295374  0.09337403 0.294368  ]

# %%
folder = general_directory_project+"cathode_norm_ranit_rand/"
rel_results, rel_error, exp= bp.bump_hunt(folder, err=ranit_SB_error)
bp.plotting(rel_results, "cathode_norm_SB", min=min_sig, max = max_sig, save=save)

rel_results, rel_error, exp = bp.bump_hunt(folder, err=ranit_Herwig_error)
bp.plotting(rel_results, "cathode_norm_Herwig", min=min_sig, max = max_sig, save=save)

err = np.array([max([ranit_Herwig_error[i],ranit_SB_error[i]]) for i in range(3)])
rel_results, rel_error, exp = bp.bump_hunt(folder, err=err)
bp.plotting(rel_results, "cathode_norm_Herwig_SB", min=min_sig, max = max_sig_Herwig, save=save)

err = np.array([np.sqrt(ranit_SB_error[i]**2+ranit_Herwig_error[i]**2) for i in range(3)])
rel_results, rel_error, exp = bp.bump_hunt(folder, err=err)
bp.plotting(rel_results, "cathode_norm_Herwig_SB_quad", min=min_sig, max = max_sig, save=save)


err = np.array([np.sqrt(ranit_SB_error[i]**2+ranit_Herwig_error[i]**2) for i in range(3)])
print("quad combine = ", err)
rel_results, rel_error, exp = bp.bump_hunt(folder, err=err, err_err=np.array([0,0,0]))
bp.plotting(rel_results, "cathode_norm_Herwig_SB_quad", min=min_sig, max = 20, save=False)
# Out:
# quad combine =  [0.07056219 0.18782464 0.93876796]

# %% [markdown]
# ## Baseline + $\Delta R$ dataset without signal

# %%
folder = general_directory+"cathode_without_DR_Herwig_ranit_rand/"
rel_results, rel_error, exp = bp.bump_hunt(folder)
ranit_Herwig_error = np.mean(rel_error,axis=(1,2))
cathode_stat = np.mean(exp,axis=(1,2))
cathode_sys_Herwig = np.std(rel_error, axis=(1,2))
print("alpha =",ranit_Herwig_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))
print("stat_error =",cathode_stat)
bp.plotting_error(rel_error, "cathode_DR_Herwig", min=min_error, max=max_error, save=save)
# Out:
# alpha = [0.11605891 0.146308   0.19561029]
# alpha_std = [0.05378413 0.09439088 0.34273836]
# stat_error = [0.02945285 0.0931063  0.29358787]

# %%
folder = general_directory_project+"cathode_without_DR_SB_stats_ranit_rand/"
rel_results, rel_error, exp = bp.bump_hunt(folder)
ranit_SB_error = np.mean(rel_error,axis=(1,2))
cathode_stat = np.mean(exp,axis=(1,2))
cathode_sys_SB = np.std(rel_error, axis=(1,2))
print("alpha =",ranit_SB_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))
print("stat_error =",cathode_stat)
bp.plotting_error(rel_error, "cathode_DR_without_SB", min=min_error, max=max_error, save=save)
# Out:
# alpha = [0.06238918 0.09720482 0.65732502]
# alpha_std = [0.05063405 0.12783587 0.55457503]
# stat_error = [0.02958956 0.09353849 0.29504946]

# %%
folder = general_directory_project+"cathode_without_DR_ranit_rand/"
rel_results, rel_error, exp = bp.bump_hunt(folder)
cathode_error = np.mean(rel_error,axis=(1,2))
cathode_stat = np.mean(exp,axis=(1,2))
cathode_sys = np.std(rel_error, axis=(1,2))
print("alpha =",cathode_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))
print("stat_error =",cathode_stat)
bp.plotting_error(rel_error, "cathode_DR_without", min=min_error, max=max_error, save=save)

rel_results, rel_error, exp = bp.bump_hunt(folder, err=ranit_SB_error)
bp.plotting(rel_results, "cathode_DR_without_SB", min=min_sig, max = max_sig_no, save=save)

rel_results, rel_error, exp = bp.bump_hunt(folder, err=ranit_Herwig_error)
bp.plotting(rel_results, "cathode_DR_without_Herwig", min=min_sig, max = max_sig_no, save=save)

err = np.array([max([ranit_Herwig_error[i],ranit_SB_error[i]]) for i in range(3)])
rel_results, rel_error, exp = bp.bump_hunt(folder, err=err)
bp.plotting(rel_results, "cathode_DR_without_Herwig_SB", min=min_sig, max = max_sig_no, save=save)

err = np.array([np.sqrt(ranit_SB_error[i]**2+ranit_Herwig_error[i]**2) for i in range(3)])
print("alpha quad combine = ", err)
rel_results, rel_error, exp = bp.bump_hunt(folder, err=err)
bp.plotting(rel_results, "cathode_DR_without_Herwig_SB_quad", min=min_sig, max = max_sig_no, save=save)

err = np.array([np.sqrt(ranit_SB_error[i]**2+ranit_Herwig_error[i]**2) for i in range(3)])
print("alpha quad combine = ", err)
rel_results, rel_error, exp = bp.bump_hunt(folder, err=err, err_err=np.array([0,0,0]))
bp.plotting(rel_results, "cathode_DR_without_Herwig_SB_quad", min=min_sig, max = max_sig_no, save=False)
# Out:
# alpha = [0.12932579 0.21802232 0.49893708]
# alpha_std = [0.05872235 0.13652673 0.48332017]
# stat_error = [0.02958956 0.09353849 0.29504946]
# alpha quad combine =  [0.13176525 0.17565537 0.68581307]
# alpha quad combine =  [0.13176525 0.17565537 0.68581307]

# %% [markdown]
# ## Baseline + $\Delta R$ dataset with signal

# %%
folder = general_directory_work+"cathode_norm_DR_SB_stats_ranit_rand/"
rel_results, rel_error, exp = bp.bump_hunt(folder)
ranit_SB_error = np.mean(rel_error,axis=(1,2))
cathode_stat = np.mean(exp,axis=(1,2))
cathode_sys_SB = np.std(rel_error, axis=(1,2))
print("alpha =",ranit_SB_error)
print("alpha_std =", np.std(rel_error, axis=(1,2)))
print("stat_error =",cathode_stat)
bp.plotting_error(rel_error, "cathode_DR_norm_SB", min=min_error, max=max_error, save=save)
# Out:
# alpha = [0.07237724 0.15607246 0.78885383]
# alpha_std = [0.06238144 0.15032744 0.6607656 ]
# stat_error = [0.02953741 0.0933741  0.29437024]

# %%
folder = general_directory_work+"cathode_norm_DR_ranit_rand/"
rel_results, rel_error, exp = bp.bump_hunt(folder, err=ranit_SB_error)
bp.plotting(rel_results, "cathode_DR_norm_SB", min=min_sig, max = max_sig, save=save)

rel_results, rel_error, exp = bp.bump_hunt(folder, err=ranit_Herwig_error)
bp.plotting(rel_results, "cathode_DR_norm_Herwig", min=min_sig, max = max_sig_Herwig, save=save)

err = np.array([max([ranit_Herwig_error[i],ranit_SB_error[i]]) for i in range(3)])
rel_results, rel_error, exp = bp.bump_hunt(folder, err=err)
bp.plotting(rel_results, "cathode_DR_norm_Herwig_SB", min=min_sig, max = max_sig, save=save)

err = np.array([np.sqrt(ranit_SB_error[i]**2+ranit_Herwig_error[i]**2) for i in range(3)])
rel_results, rel_error, exp = bp.bump_hunt(folder, err=err)
bp.plotting(rel_results, "cathode_DR_norm_Herwig_SB_quad", min=min_sig, max = max_sig, save=save)

err = np.array([np.sqrt(ranit_SB_error[i]**2+ranit_Herwig_error[i]**2) for i in range(3)])
print("quad combine = ", err)
rel_results, rel_error, exp = bp.bump_hunt(folder, err=err, err_err = np.array([0,0,0]))
bp.plotting(rel_results, "cathode_DR_norm_Herwig_SB_quad", min=min_sig, max = 20, save=False)
# Out:
# quad combine =  [0.13677769 0.21392672 0.81274458]
